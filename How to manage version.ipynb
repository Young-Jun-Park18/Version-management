# %% [markdown]
# # 1. Github 회원가입

# %%
# https://github.com/

# %% [markdown]
# # 2. Git 설치

# %%
# https://git-scm.com/downloads/win

# %% [markdown]
# ![2.PNG](attachment:2.PNG)

# %% [markdown]
# # 3. Git bash here

# %%
# 폴더를 생성하고 폴더 내부에서 우클릭 -> git bash here 클릭

# %% [markdown]
# ![3.PNG](attachment:3.PNG)

# %% [markdown]
# # 4. git init ( 시작폴더 지정 )

# %%
# git init 이라는 명령어는 현재 내가 선택한 폴더가 git 시작지점이야라고 알려주는 것

# %% [markdown]
# ![4.PNG](attachment:4.PNG)

# %% [markdown]
# # 5. touch sample.txt ( 파일 생성 )

# %%
# touch는 생성하는 명령어이다.
# 해당 폴더에 sample이라는 이름을 가진 txt 파일이 생성된다
# 우클릭 -> 새로만들기 -> 텍스트파일생성 이 동작과 같은 결과이다

# %% [markdown]
# ![5.PNG](attachment:5.PNG)

# %% [markdown]
# # 6. git status ( 현재 상황 출력 )

# %%
# git status는 현재 깃 상태를 확인하는 명령어이다.

# %% [markdown]
# ![6.PNG](attachment:6.PNG)

# %%
# on branch master No commits yet : 아직 마스터 가지에서 커밋한게 아직 없다라고 나옴
# 현재 생성된 파일 이름이 나옴
# commit이란, 현재 내 작업 결과의 순간을 스냅샷으로 찰칵 찍어서 기록하는거라고 생각하면 됨

# %% [markdown]
# # 7. git add 파일명.확장자 (현재 상태 인식시키기)

# %%
# git add sample.txt를 통해 6번의 Untracked files을 해결한다. (파일 추적)
# 다시 git status를 해주면 Untracked files 문제는 해결된다.
# 하지만 여전히 No commits yet은 남아있는상태

# %% [markdown]
# ![7.PNG](attachment:7.PNG)

# %% [markdown]
# # 8. git commit -m "내용" ( 마스터 브랜치에 내용 커밋 )

# %%
# 우리는 Untracked files을 해결했고, 이제 No commits yet 부분을 건들자
# git commit -m "내용"은 깃에 스냅샷을 찍을건데 -m 마스터 브랜치이고 "내용"을 추가할거야 라는 의미이다

# %% [markdown]
# ![8.PNG](attachment:8.PNG)

# %%
# 그러면 git에서 너가 누군지 이메일과 이름을 입력하라고 요청한다
# 본인의 깃허브 이메일과 깃허브 이름을 입력하면 된다

# %% [markdown]
# ![9.PNG](attachment:9.PNG)

# %%
# 다시 커밋을 해주면, 고유 코드가 생성되고 이 버전으로 언제든지 돌아올 수 있다

# %% [markdown]
# # 9. git remote add origin 주소 ( 깃허브와 연동 )

# %%
# 이 명령어는 git에서 remote(원격으로) 내 깃허브 repository에 add 해줘 라는 명령어입니다
# 본인의 repository 주소는 깃허브 해당 저장소에 들어가면 나옴

# %% [markdown]
# ![9.1.PNG](attachment:9.1.PNG)

# %% [markdown]
# ![9.2.PNG](attachment:9.2.PNG)

# %%
# 여기까지가 지금 내 repository랑 연결만 해놓은 상태입니다. 
# 아직 sample.txt는 업로드하지 않은 것임.

# %% [markdown]
# # 10. git push origin master ( repository에 업로드)

# %%
# done 이라는 메세지가 뜨고, 깃허브 저장소에 들어가보면 업로드 된 것을 확인할 수 있다.

# %% [markdown]
# ![10.PNG](attachment:10.PNG)

# %% [markdown]
# # 11. 추가작업하기

# %% [markdown]
# # 12. 다시 git add 파일명.확장자

# %% [markdown]
# # 13. git commit -m "추가작업커밋"

# %% [markdown]
# # 14. git push origin master

# %%
# 항상 add -> commit -> push 순서임을 명심하기

# %% [markdown]
# # 15. 확인하는 방법

# %% [markdown]
# ![12.PNG](attachment:12.PNG)

# %% [markdown]
# ![13.PNG](attachment:13.PNG)

# %% [markdown]
# ![14.PNG](attachment:14.PNG)

# %%
# 업로드된 게시글에 들어가서 
# History에 들어가면
# 처음 push 했던 것과, 추가작업을 해서 다시 push한게 있는 것을 볼 수 있다.

# %% [markdown]
# # 16. git pull origin master ( 공동작업이나 다른 pc로 작업할 때 )

# %%
# 다른 사람의 버전과 내 버전이 틀릴 때 push 해버리면 error가 남 그래서 git pull origin master를 먼저 해주고
# ===== 이 표시는 충돌이 난 부분이니 적절히 수정해주고
# 그 이후 add -> commit -> push를 해줘야함

# %% [markdown]
# # ---------------------------------------------------------------------------------------------

# %% [markdown]
# # 1. 명령어를 사용하지 않고 편안하게 하는 방법 (Sourcetree)

# %%
# https://sourcetreeapp.com/ 접속

# %% [markdown]
# ![a.PNG](attachment:a.PNG)

# %% [markdown]
# ![b.PNG](attachment:b.PNG)

# %% [markdown]
# ![c.PNG](attachment:c.PNG)

# %% [markdown]
# ![d.PNG](attachment:d.PNG)

# %%
# 작업할 폴더를 생성하고 폴더를 선택한다

# %% [markdown]
# ![e.PNG](attachment:e.PNG)

# %%
# 적합한 작업중인 경로가 아니라고 뜨는 것은 해당 폴더에서 git bash here를 누르고 git init을 해줘야 해결된다

# %% [markdown]
# ![f.PNG](attachment:f.PNG)

# %% [markdown]
# ![g.PNG](attachment:g.PNG)

# %% [markdown]
# # 2. 작업하고 올리는 방법

# %%
# 우선 폴더에 작업할 파일을 한 개 생성한다

# %% [markdown]
# ![i.PNG](attachment:i.PNG)

# %%
# Sourcetree program에서 새로고침을 누른다

# %% [markdown]
# ![j.PNG](attachment:j.PNG)

# %%
# 스테이지란?
# 내 컴퓨터인 로컬과 모두가 볼 수 있는 깃허브 사이에 중간 지점입니다.
# add한다고 바로 깃허브 repository에 업로드되지 않는 것처럼
# 가상의 공간인 스테이지에서 commit을 하고 저장소에 pull or push를 할 수 있습니다.

# %% [markdown]
# ![k.PNG](attachment:k.PNG)

# %%
# 스테이지에 내가 원하는 파일을 올려놓고

# %% [markdown]
# ![l.PNG](attachment:l.PNG)

# %%
# 커밋 내용을 작성한 뒤 커밋한다

# %% [markdown]
# # 3. 저장소 경로 설정하는 방법

# %%
# 깃허브 저장소에 주소를 복사한 뒤

# %% [markdown]
# ![m.PNG](attachment:m.PNG)

# %%
# sourcetree에서 설정 클릭

# %% [markdown]
# ![n.PNG](attachment:n.PNG)

# %%
# 원격이름 (저장소 이름), url(깃허브 저장소 주소), generic account, 사용자명을 적어주고 확인

# %% [markdown]
# ![p.PNG](attachment:p.PNG)

# %% [markdown]
# # 4. pull or push

# %% [markdown]
# ![s.PNG](attachment:s.PNG)

# %%
# 항상 pull로 다른 개발자가 수정해서 업데이트 된 내용을 먼저 불러오고
# 그 이후 push를 해야 오류가 안 난다
