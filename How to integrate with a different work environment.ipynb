# %% [markdown]
# # 1. sourcetree download

# %% [markdown]
# # 2. 새 VScode 창 열고 리포지토리 복제 클릭

# %% [markdown]
# ![image.png](attachment:2e6dcaba-bca0-4f75-ab9a-568f948f58aa.png)

# %% [markdown]
# # 3. 본인의 저장소 주소 입력

# %% [markdown]
# ![image.png](attachment:319f7390-fc5c-48fa-8b0a-78612e63c89d.png)

# %% [markdown]
# # 4. 가져온 코드로 추가 작업을 하고 github와 연결
